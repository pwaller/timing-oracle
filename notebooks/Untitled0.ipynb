# %%
import numpy as N, scipy as S, matplotlib.pylab as P

# %%
P.hist([int(x) for x in open("samples.txt") if x.strip()], bins=300,range=(100000, 2e6));

# %%
P.hist([int(x) for x in open("samples-half.txt") if x.strip()], bins=300,range=(100000, 2e6));

# %%
P.hist([int(x) for x in open("samples-none.txt") if x.strip()], bins=300, range=(1e5, 2e6));

# %% [markdown]
# ### Notes:
#
# * It's quite modal. So the model needs to be: there are an unknown number of modes, each mode introduces a different random amount of latency.
# * A sample comes from a given mode.
# * We're trying to measure a parameter which is hidden my the random latency
# * Each sample should cause a belief update, which could mean introducing another mode, or..
